# %% [markdown]
# #GR5072 HW1

# %% [markdown]
# ***Question 1*** Create a Jupyter Notebook

# %% [markdown]
# This is a data science blog that I found out recently: [medium.com/@rustezeny](hhttps://medium.com/@rustezeny//)
# ![Question 1-Data Science Blog.png](data:image/png;base64,...)

# %% [markdown]
# ***Question 2*** Markdown quote

# %% [markdown]
# > "Take a step back and there will be a bigger world in front of you."
# ——*Chinese Provebs*

# %% [markdown]
# ***Question 3*** Latex formula and plot

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(0,1000,2)
y=np.square(x)
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# $$y=x^2$$

# %% [markdown]
# ***Question 4*** Markdown table

# %% [markdown]
# | Python Package      | Github Stars |
# | ----------- | ----------- |
# | TensorFlow (tensorflow/tensorflow) | 168k      |
# | Home Assistant (home-assistant/core)  | 54.9k        |
# | PyTorch  | 59k        |
# | Microsoft Azure CLI (Azure/azure-cli)  | 3.2k        |
# | pandas (pandas-dev/pandas)  | 35.3k        |

# %% [markdown]
# ***Question 5*** Execute shell command

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# ***Question 6*** Run some external script

# %%
ls /content/drive/MyDrive/Colab\ Notebooks
# Out:
#  111.py
# 'Machine Learning SOSC Class 2.ipynb'
# '“Te Lai Econ_204_EconomicGrowth: Tuesday.ipynb”的副本'
# '“Te Lai Econ_204_EconomicGrowth: Tuesday.ipynb”的副本 (1)'
#  Untitled0.ipynb
# 'Xinyi Shi: Econ_204_EconomicGrowth: Tuesday.ipynb”'
# 'Xinyi. Shi “Econ204 Rational Expetation Theory: Inflation and Interest.ipynb”'
# 'Xinyi Shi-GR5072 HW1.ipynb'
# 'Xinyi Shi-GR5073 HW1.ipynb'
# '“Xinyi Shi-GR5073 HW1.ipynb”的副本'

# %%
import answer from ColabNotebooks
# Out:
#   File "<ipython-input-25-5149d99fa2b9>", line 1
#     import answer from ColabNotebooks
#                      ^
# SyntaxError: invalid syntax
