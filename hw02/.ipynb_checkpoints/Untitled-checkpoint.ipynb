# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **1. Peaks**

# %% [markdown]
# a) What proportion of peaks is still unclimbed?

# %%
peaks = pd.read_csv("data/peaks.csv")

# %%
peaks.shape
# Out:
# (468, 8)

# %%
peaks.head()
# Out:
#   peak_id      peak_name peak_alternative_name  height_metres climbing_status  \
# 0    AMAD     Ama Dablam          Amai Dablang           6814         Climbed
# 1    AMPG  Amphu Gyabjen                   NaN           5630         Climbed
# 2    ANN1    Annapurna I                   NaN           8091         Climbed
# 3    ANN2   Annapurna II                   NaN           7937         Climbed
# 4    ANN3  Annapurna III                   NaN           7555         Climbed
#
#    first_ascent_year  first_ascent_country first_ascent_expedition_id
# 0             1961.0  New Zealand, USA, UK                  AMAD61101
# 1             1953.0                    UK                  AMPG53101
# 2             1950.0                France                  ANN150101
# 3             1960.0             UK, Nepal                  ANN260101
# 4             1961.0                 India                  ANN361101

# %%
peaks_unclimbed = peaks[peaks['climbing_status'] == 'Unclimbed']
peaks_unclimbed.describe()
# Out:
#        height_metres  first_ascent_year
# count     127.000000                1.0
# mean     6523.330709             2018.0
# std       407.684422                NaN
# min      5407.000000             2018.0
# 25%      6251.000000             2018.0
# 50%      6500.000000             2018.0
# 75%      6690.500000             2018.0
# max      8077.000000             2018.0

# %% [markdown]
# Answer: <br>
# Unclimed Peaks/All Peaks = 127/468 = 0.2713 = 27.13%<br>
# The proportion of peaks unclimbed is 27.13%.<br>

# %% [markdown]
# b) What is the average height of the climbed peaks vs. unclimbed peaks?

# %%
peaks_climbed = peaks[peaks['climbing_status'] == 'Climbed']
peaks_climbed.describe()
# Out:
#        height_metres  first_ascent_year
# count     341.000000         335.000000
# mean     6706.284457        1978.961194
# std       615.268778         100.332688
# min      5550.000000         201.000000
# 25%      6227.000000        1963.000000
# 50%      6609.000000        1982.000000
# 75%      7030.000000        2008.000000
# max      8850.000000        2019.000000

# %% [markdown]
# Answer: <br>
# The result shows no outliers outliers in the data of the height of the peaks.Therefore, we can draw some conclusions from it.<br>
# The average height of the climbed peaks is 6706.28 meters and the average height of the unclimbed peaks is 6523.33 meters.

# %% [markdown]
# **2. Sherpas**

# %%
members = pd.read_csv("data/members.csv")

# %%
members.head()
# Out:
#   expedition_id     member_id peak_id   peak_name  year  season sex   age  \
# 0     AMAD78301  AMAD78301-01    AMAD  Ama Dablam  1978  Autumn   M  40.0
# 1     AMAD78301  AMAD78301-02    AMAD  Ama Dablam  1978  Autumn   M  41.0
# 2     AMAD78301  AMAD78301-03    AMAD  Ama Dablam  1978  Autumn   M  27.0
# 3     AMAD78301  AMAD78301-04    AMAD  Ama Dablam  1978  Autumn   M  40.0
# 4     AMAD78301  AMAD78301-05    AMAD  Ama Dablam  1978  Autumn   M  34.0
#
#   citizenship expedition_role  ...  highpoint_metres  success   solo  \
# 0      France          Leader  ...               NaN    False  False
# 1      France   Deputy Leader  ...            6000.0    False  False
# 2      France         Climber  ...               NaN    False  False
# 3      France      Exp Doctor  ...            6000.0    False  False
# 4      France         Climber  ...               NaN    False  False
#
#    oxygen_used   died  death_cause death_height_metres  injured  injury_type  \
# 0        False  False          NaN                 NaN    False          NaN
# 1        False  False          NaN                 NaN    False          NaN
# 2        False  False          NaN                 NaN    False          NaN
# 3        False  False          NaN                 NaN    False          NaN
# 4        False  False          NaN                 NaN    False          NaN
#
#   injury_height_metres
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# Using the members data only, select a subset of all persons who have a Nepalese citizenship.

# %%
Nepalese = members[members['citizenship'] == "Nepal"]

# %% [markdown]
# a) What proportion of them was hired for the expedition?

# %%
Nepalese.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16135 entries, 24 to 76518
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   expedition_id         16135 non-null  object
#  1   member_id             16135 non-null  object
#  2   peak_id               16135 non-null  object
#  3   peak_name             16131 non-null  object
#  4   year                  16135 non-null  int64
#  5   season                16135 non-null  object
#  6   sex                   16135 non-null  object
#  7   age                   14373 non-null  float64
#  8   citizenship           16135 non-null  object
#  9   expedition_role       16133 non-null  object
#  10  hired                 16135 non-null  bool
#  11  highpoint_metres      14247 non-null  float64
#  12  success               16135 non-null  bool
#  13  solo                  16135 non-null  bool
#  14  oxygen_used           16135 non-null  bool
#  15  died                  16135 non-null  bool
#  16  death_cause           315 non-null    object
#  17  death_height_metres   297 non-null    float64
#  18  injured               16135 non-null  bool
#  19  injury_type           152 non-null    object
#  20  injury_height_metres  122 non-null    float64
# dtypes: bool(6), float64(4), int64(1), object(10)
# memory usage: 2.1+ MB

# %%
NepaleseHired = Nepalese[Nepalese['expedition_role'] == 'H-A Worker']
NepaleseHired.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14279 entries, 24 to 76518
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   expedition_id         14279 non-null  object
#  1   member_id             14279 non-null  object
#  2   peak_id               14279 non-null  object
#  3   peak_name             14277 non-null  object
#  4   year                  14279 non-null  int64
#  5   season                14279 non-null  object
#  6   sex                   14279 non-null  object
#  7   age                   12877 non-null  float64
#  8   citizenship           14279 non-null  object
#  9   expedition_role       14279 non-null  object
#  10  hired                 14279 non-null  bool
#  11  highpoint_metres      13148 non-null  float64
#  12  success               14279 non-null  bool
#  13  solo                  14279 non-null  bool
#  14  oxygen_used           14279 non-null  bool
#  15  died                  14279 non-null  bool
#  16  death_cause           219 non-null    object
#  17  death_height_metres   213 non-null    float64
#  18  injured               14279 non-null  bool
#  19  injury_type           116 non-null    object
#  20  injury_height_metres  97 non-null     float64
# dtypes: bool(6), float64(4), int64(1), object(10)
# memory usage: 1.8+ MB

# %% [markdown]
# Answer:<br>
# Hired Nepalese / All Nepalese = 14279/16135 = 0.8850 = 88.5%<br>
# The proportion of Nepalese members who were hired for expedition is 88.5%.

# %% [markdown]
# b) What are their minimum, maximum, and average ages?

# %%
Nepalese.describe()
# Out:
#                year           age  highpoint_metres  death_height_metres  \
# count  16135.000000  14373.000000      14247.000000           297.000000
# mean    2005.505671     32.885062       7878.236190          6059.461279
# std       14.479732      7.746973        987.588329          1277.859557
# min     1921.000000     12.000000       3800.000000          2100.000000
# 25%     2002.000000     27.000000       6977.000000          5350.000000
# 50%     2010.000000     32.000000       8188.000000          6000.000000
# 75%     2015.000000     38.000000       8850.000000          6800.000000
# max     2019.000000     85.000000       8850.000000          8800.000000
#
#        injury_height_metres
# count            122.000000
# mean            6886.147541
# std             1116.734982
# min             4600.000000
# 25%             6050.000000
# 50%             6900.000000
# 75%             7800.000000
# max             8880.000000

# %%
NepaleseHired.describe()
# Out:
#                year           age  highpoint_metres  death_height_metres  \
# count  14279.000000  12877.000000      13148.000000           213.000000
# mean    2006.776035     32.797701       7902.146562          6449.483568
# std       13.480210      7.679750        974.865263          1036.122906
# min     1921.000000     15.000000       3800.000000          4200.000000
# 25%     2004.000000     27.000000       7000.000000          5790.000000
# 50%     2010.000000     32.000000       8188.000000          6400.000000
# 75%     2015.000000     38.000000       8850.000000          7000.000000
# max     2019.000000     67.000000       8850.000000          8800.000000
#
#        injury_height_metres
# count             97.000000
# mean            6845.515464
# std             1081.711964
# min             4600.000000
# 25%             6050.000000
# 50%             6950.000000
# 75%             7500.000000
# max             8880.000000

# %% [markdown]
# Answer:<br>
# The minimum age of all Nepalese members is 12 years old. The maximum age of all Nepalese members is 85 years old. The average age of all Nepalese members is about 33 years old.<br>
# The minimum age of hired Nepalese members is 15. The maximum age of hired Nepalese members is 67. The average age of hired Nepalese members is about 33 years old.

# %% [markdown]
# **3. Gender**

# %% [markdown]
# Now use all three data sets and join them on the provided ID variables. For this question, limit yourself to the subset of non-hired participants.

# %%
selected_expeditions = expeditions[['expedition_id', 'peak_name', 'year','basecamp_date','highpoint_date','highpoint_metres']].drop_duplicates() 
selected_expeditions.head(2)
# Out:
#   expedition_id     peak_name  year basecamp_date highpoint_date  \
# 0     ANN260101  Annapurna II  1960    1960-03-15     1960-05-17
# 1     ANN269301  Annapurna II  1969    1969-09-25     1969-10-22
#
#    highpoint_metres
# 0            7937.0
# 1            7937.0

# %%
members.head(2)
# Out:
#   expedition_id     member_id peak_id   peak_name  year  season sex   age  \
# 0     AMAD78301  AMAD78301-01    AMAD  Ama Dablam  1978  Autumn   M  40.0
# 1     AMAD78301  AMAD78301-02    AMAD  Ama Dablam  1978  Autumn   M  41.0
#
#   citizenship expedition_role  ...  highpoint_metres  success   solo  \
# 0      France          Leader  ...               NaN    False  False
# 1      France   Deputy Leader  ...            6000.0    False  False
#
#    oxygen_used   died  death_cause death_height_metres  injured  injury_type  \
# 0        False  False          NaN                 NaN    False          NaN
# 1        False  False          NaN                 NaN    False          NaN
#
#   injury_height_metres
# 0                  NaN
# 1                  NaN
#
# [2 rows x 21 columns]

# %% [markdown]
# a) What is the first record of a woman summitting a peak? Which peak (name and height in meters) was that?

# %%
selected_members = members[['expedition_id','peak_name','year','sex','expedition_role','highpoint_metres','success']].drop_duplicates()
female_members = selected_members[selected_members['sex'] == "F" ]
female_members_success = female_members[female_members['success'] == True ]
female_members_success.head(2)
# Out:
#     expedition_id   peak_name  year sex expedition_role  highpoint_metres  \
# 108     AMAD82101  Ama Dablam  1982   F         Climber            6814.0
# 110     AMAD82101  Ama Dablam  1982   F          Leader            6814.0
#
#      success
# 108     True
# 110     True

# %%
female_members_success['year'].describe()
# Out:
# count    1643.000000
# mean     2007.177724
# std        10.358910
# min      1949.000000
# 25%      2003.000000
# 50%      2009.000000
# 75%      2015.000000
# max      2019.000000
# Name: year, dtype: float64

# %%
female_expeditions = pd.merge(female_members_success, selected_expeditions, 
                                how='outer', on = "expedition_id")
female_expeditions.head(2)
# Out:
#   expedition_id peak_name_x  year_x sex expedition_role  highpoint_metres_x  \
# 0     AMAD82101  Ama Dablam  1982.0   F         Climber              6814.0
# 1     AMAD82101  Ama Dablam  1982.0   F          Leader              6814.0
#
#   success peak_name_y  year_y basecamp_date highpoint_date  highpoint_metres_y
# 0    True  Ama Dablam    1982    1982-04-03     1982-04-20              6814.0
# 1    True  Ama Dablam    1982    1982-04-03     1982-04-20              6814.0

# %%
female_expeditions.describe()
female_expeditions.head()
# Out:
#   expedition_id peak_name_x  year_x sex expedition_role  highpoint_metres_x  \
# 0     AMAD82101  Ama Dablam  1982.0   F         Climber              6814.0
# 1     AMAD82101  Ama Dablam  1982.0   F          Leader              6814.0
# 2     AMAD82101  Ama Dablam  1982.0   F   Deputy Leader              6814.0
# 3     AMAD82101  Ama Dablam  1982.0   F      Exp Doctor              6814.0
# 4     AMAD83301  Ama Dablam  1983.0   F         Climber              6814.0
#
#   success peak_name_y  year_y basecamp_date highpoint_date  highpoint_metres_y
# 0    True  Ama Dablam    1982    1982-04-03     1982-04-20              6814.0
# 1    True  Ama Dablam    1982    1982-04-03     1982-04-20              6814.0
# 2    True  Ama Dablam    1982    1982-04-03     1982-04-20              6814.0
# 3    True  Ama Dablam    1982    1982-04-03     1982-04-20              6814.0
# 4    True  Ama Dablam    1983    1983-10-08     1983-10-22              6814.0

# %%
first_female = female_expeditions[female_expeditions['year']==1949]
first_female
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [124], in <cell line: 1>()
# ----> 1 first_female = female_expeditions[female_expeditions['year']==1949]
#       2 first_female
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'year'

# %% [markdown]
# Answer:<bk>
# The first record of a woman summitting a peak is in the year 1949.

# %% [markdown]
# b) Provide a single cross-tab table of the sex of an expedition participant and - the proportion of success in summitting a main peak or sub-peak
# - the proportion of participants using oxygen support - the proportion of participants who died.
#
# That is, sex should be displayed as the rows of the output and the three requested proportions as its columns.

# %%
female_members.info()
female_members_success.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5347 entries, 25 to 76517
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   expedition_id     5347 non-null   object
#  1   peak_name         5347 non-null   object
#  2   year              5347 non-null   int64
#  3   sex               5347 non-null   object
#  4   expedition_role   5345 non-null   object
#  5   highpoint_metres  3684 non-null   float64
#  6   success           5347 non-null   bool
# dtypes: bool(1), float64(1), int64(1), object(4)
# memory usage: 297.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1643 entries, 108 to 76467
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   expedition_id     1643 non-null   object
#  1   peak_name         1643 non-null   object
#  2   year              1643 non-null   int64
#  3   sex               1643 non-null   object
#  4   expedition_role   1643 non-null   object
#  5   highpoint_metres  1643 non-null   float64
#  6   success           1643 non-null   bool
# dtypes: bool(1), float64(1), int64(1), object(4)
# memory usage: 91.5+ KB

# %%
male_members = members[members['sex'] == "M" ]
male_members_success = male_members[male_members['success'] == True ]
male_members.info()
male_members_success.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69473 entries, 0 to 76518
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   expedition_id         69473 non-null  object
#  1   member_id             69473 non-null  object
#  2   peak_id               69473 non-null  object
#  3   peak_name             69458 non-null  object
#  4   year                  69473 non-null  int64
#  5   season                69473 non-null  object
#  6   sex                   69473 non-null  object
#  7   age                   66186 non-null  float64
#  8   citizenship           69463 non-null  object
#  9   expedition_role       69454 non-null  object
#  10  hired                 69473 non-null  bool
#  11  highpoint_metres      49984 non-null  float64
#  12  success               69473 non-null  bool
#  13  solo                  69473 non-null  bool
#  14  oxygen_used           69473 non-null  bool
#  15  died                  69473 non-null  bool
#  16  death_cause           1056 non-null   object
#  17  death_height_metres   1020 non-null   float64
#  18  injured               69473 non-null  bool
#  19  injury_type           1562 non-null   object
#  20  injury_height_metres  908 non-null    float64
# dtypes: bool(6), float64(4), int64(1), object(10)
# memory usage: 8.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26891 entries, 9 to 76518
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   expedition_id         26891 non-null  object
#  1   member_id             26891 non-null  object
#  2   peak_id               26891 non-null  object
#  3   peak_name             26877 non-null  object
#  4   year                  26891 non-null  int64
#  5   season                26891 non-null  object
#  6   sex                   26891 non-null  object
#  7   age                   25838 non-null  float64
#  8   citizenship           26891 non-null  object
#  9   expedition_role       26888 non-null  object
#  10  hired                 26891 non-null  bool
#  11  highpoint_metres      26891 non-null  float64
#  12  success               26891 non-null  bool
#  13  solo                  26891 non-null  bool
#  14  oxygen_used           26891 non-null  bool
#  15  died                  26891 non-null  bool
#  16  death_cause           224 non-null    object
#  17  death_height_metres   218 non-null    float64
#  18  injured               26891 non-null  bool
#  19  injury_type           355 non-null    object
#  20  injury_height_metres  237 non-null    float64
# dtypes: bool(6), float64(4), int64(1), object(10)
# memory usage: 3.4+ MB
