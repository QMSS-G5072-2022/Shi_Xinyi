# %% [markdown]
# # Modern Data Structures - Final Project Proposal

# %% [markdown]
# ## Brief description of the purpose

# %% [markdown]
# This project will be using CryptingUp API and create an API client that mainly comprises of two functionalities. First is to allow users to access the cryptocurrency information, markets and exchanges data, and the second will allow users to have a look at the crypocurrency exchange price in specific assets/markets.

# %% [markdown]
# ## Links to data sources / API etc

# %% [markdown]
# API Portal / Home Page: https://cryptingup.com/apidoc/#introduction
#
# Authenticaiton: This API requires no key to access.
#
# Compnaies information can be retrieved via a URL and returned in JSON format. Example URL: https://cryptingup.com/api/.
#
# Paramerers:
# Specifying Pagination
# size - Number of results per request
# start - Start point of results
#
# Example of the exchange request:
#  ![parameter.png](attachment:parameter.png)

# %% [markdown]
# Example of the asset request:
# ![asset.png](attachment:asset.png)

# %% [markdown]
# ## Outline the technical steps / challenges you plan to address and include in your submission

# %% [markdown]
# 1. Query API to obtain data from CryptingUp with parameters specified (asset/market )
#
# 2. Handle, parse, and transform JSON return into a python dataframe
#
# 3. Clean data, all the null inputs for the concerned variables will be removed
#
# 4. Provide summary statistics on the price of transactions, assets, and markets
#
# 5. Wrap up everything in a function/python package (undecided)

# %% [markdown]
# ## Are there any significant hurdles that you have doubts about? Would not solving them render the project incomplete?

# %% [markdown]
# 1. There are many features and requests I can choose from, and I am not sure which one to choose and do my analysis. For example, I can retrieve the exchange, market, and asset data, and they all contain prices. Should I focus on one request and one parameter(price) for my function for now?
#
# 2. I need to learn more about the markets of cryptocurrencies and understand the concepts of asset, price, spread, and volume. But I think this is not a significant hurdle.
